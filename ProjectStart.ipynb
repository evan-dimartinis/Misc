# %%
import praw
import pandas as pd
import time
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %%
reddit = praw.Reddit(client_id='nfgFdWocI1GFIQ',
                    client_secret='z_rsAXFyjZ3fELcJKucmHsQIB3jgHQ',
                    password='447account',
                    user_agent='447 Example',
                    username='Traditional-Ad-9640')
news = reddit.subreddit('News')


yesterdays_news = news.random()

topics_dict={"title":[],\
                "score":[],\
                "id":[],\
                "url":[],\
                "coms_num":[],\
                "author":[],\
                "upvotes":[],\
                }
x = 0

while x < 500:
    x+=1
    time.sleep(.5)
    post = news.random()
    if isinstance(post, praw.models.reddit.submission.Submission):
        topics_dict["title"].append(post.title)
        topics_dict["score"].append(post.score)
        topics_dict["id"].append(post.id)
        topics_dict["url"].append(post.url)
        topics_dict["coms_num"].append(post.num_comments)
        topics_dict["author"].append(post.author)
        topics_dict["upvotes"].append(post.ups)

df = pd.DataFrame(data=topics_dict)
df
# Out:
#                                                  title  score      id  \
# 0    The Hartford agrees to pay $650M in Boy Scouts...     45  msfits
# 1    Jacksonville pastor arrested, accused of moles...    573  msplo5
# 2    Former NYPD officer from Oceanside involved in...    215  mspmy8
# 3    Myanmar's junta leader 'confirmed' attending A...     19  msn401
# 4    LA County's COVID-19 positivity rate at 1%, lo...    159  mso9px
# ..                                                 ...    ...     ...
# 441  Myanmar releases prisoners for New Year, thoug...     24  msoxsd
# 442  VIDEO: Driver jumps Daytona Beach drawbridge a...     35  mslyla
# 443  Second Arrest Made After Burleson Officer Shot...    110  ms11l7
# 444  China resolutely opposed to U.S., Japan joint ...     39  msoi0o
# 445  Brazil asks women 'if possible' to delay pregn...     46  mso34l
#
#                                                    url  coms_num  \
# 0    https://abcnews.go.com/US/wireStory/hartford-a...        24
# 1    https://www.firstcoastnews.com/mobile/article/...        78
# 2    https://www.liherald.com/lynbrook/stories/form...        20
# 3    https://www.straitstimes.com/asia/se-asia/myan...         1
# 4    https://abc7.com/health/la-countys-covid-19-po...        10
# ..                                                 ...       ...
# 441  https://www.reuters.com/world/asia-pacific/mya...         3
# 442  https://www.news4jax.com/news/florida/2021/04/...        21
# 443  https://www.nbcdfw.com/news/local/second-arres...        12
# 444  https://www.reuters.com/world/china/china-reso...        20
# 445  https://edition.cnn.com/2021/04/17/americas/br...        10
#
#              author  upvotes
# 0              -___       45
# 1        Jean_Zombi      573
# 2        Jean_Zombi      215
# 3    notice_me_mina       19
# 4      Hermitically      159
# ..              ...      ...
# 441   mayurbhattseo       24
# 442  brashendeavors       35
# 443      Jean_Zombi      110
# 444     harsha_shun       39
# 445        kksingh1       46
#
# [446 rows x 7 columns]

# %%
df['title']=df['title'].str.replace('[^A-Za-z0-9 ]','',regex=True)
df['word_count'] = df['title'].apply(lambda x: len(str(x).split(" ")))
df
# Out:
#                                                  title  score      id  \
# 0    The Hartford agrees to pay 650M in Boy Scouts ...     45  msfits
# 1    Jacksonville pastor arrested accused of molest...    573  msplo5
# 2    Former NYPD officer from Oceanside involved in...    215  mspmy8
# 3    Myanmars junta leader confirmed attending Asea...     19  msn401
# 4    LA Countys COVID19 positivity rate at 1 lowest...    159  mso9px
# ..                                                 ...    ...     ...
# 441  Myanmar releases prisoners for New Year though...     24  msoxsd
# 442  VIDEO Driver jumps Daytona Beach drawbridge af...     35  mslyla
# 443  Second Arrest Made After Burleson Officer Shot...    110  ms11l7
# 444  China resolutely opposed to US Japan joint sta...     39  msoi0o
# 445  Brazil asks women if possible to delay pregnan...     46  mso34l
#
#                                                    url  coms_num  \
# 0    https://abcnews.go.com/US/wireStory/hartford-a...        24
# 1    https://www.firstcoastnews.com/mobile/article/...        78
# 2    https://www.liherald.com/lynbrook/stories/form...        20
# 3    https://www.straitstimes.com/asia/se-asia/myan...         1
# 4    https://abc7.com/health/la-countys-covid-19-po...        10
# ..                                                 ...       ...
# 441  https://www.reuters.com/world/asia-pacific/mya...         3
# 442  https://www.news4jax.com/news/florida/2021/04/...        21
# 443  https://www.nbcdfw.com/news/local/second-arres...        12
# 444  https://www.reuters.com/world/china/china-reso...        20
# 445  https://edition.cnn.com/2021/04/17/americas/br...        10
#
#              author  upvotes  word_count
# 0              -___       45          10
# 1        Jean_Zombi      573           8
# 2        Jean_Zombi      215          16
# 3    notice_me_mina       19          10
# 4      Hermitically      159          12
# ..              ...      ...         ...
# 441   mayurbhattseo       24          10
# 442  brashendeavors       35          11
# 443      Jean_Zombi      110          11
# 444     harsha_shun       39          13
# 445        kksingh1       46          11
#
# [446 rows x 8 columns]

# %%
df['title']=df['title'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df
# Out:
#                                                  title  score      id  \
# 0    the hartford agrees to pay 650m in boy scouts ...     45  msfits
# 1    jacksonville pastor arrested accused of molest...    573  msplo5
# 2    former nypd officer from oceanside involved in...    215  mspmy8
# 3    myanmars junta leader confirmed attending asea...     19  msn401
# 4    la countys covid19 positivity rate at 1 lowest...    159  mso9px
# ..                                                 ...    ...     ...
# 441  myanmar releases prisoners for new year though...     24  msoxsd
# 442  video driver jumps daytona beach drawbridge af...     35  mslyla
# 443  second arrest made after burleson officer shot...    110  ms11l7
# 444  china resolutely opposed to us japan joint sta...     39  msoi0o
# 445  brazil asks women if possible to delay pregnan...     46  mso34l
#
#                                                    url  coms_num  \
# 0    https://abcnews.go.com/US/wireStory/hartford-a...        24
# 1    https://www.firstcoastnews.com/mobile/article/...        78
# 2    https://www.liherald.com/lynbrook/stories/form...        20
# 3    https://www.straitstimes.com/asia/se-asia/myan...         1
# 4    https://abc7.com/health/la-countys-covid-19-po...        10
# ..                                                 ...       ...
# 441  https://www.reuters.com/world/asia-pacific/mya...         3
# 442  https://www.news4jax.com/news/florida/2021/04/...        21
# 443  https://www.nbcdfw.com/news/local/second-arres...        12
# 444  https://www.reuters.com/world/china/china-reso...        20
# 445  https://edition.cnn.com/2021/04/17/americas/br...        10
#
#              author  upvotes  word_count
# 0              -___       45          10
# 1        Jean_Zombi      573           8
# 2        Jean_Zombi      215          16
# 3    notice_me_mina       19          10
# 4      Hermitically      159          12
# ..              ...      ...         ...
# 441   mayurbhattseo       24          10
# 442  brashendeavors       35          11
# 443      Jean_Zombi      110          11
# 444     harsha_shun       39          13
# 445        kksingh1       46          11
#
# [446 rows x 8 columns]

# %%
stop = stopwords.words('english')
df['title'] = df['title'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df
# Out:
#                                                  title  score      id  \
# 0          hartford agre pay 650m boy scout bankruptci     45  msfits
# 1          jacksonvil pastor arrest accus molest child    573  msplo5
# 2    former nypd offic oceansid involv alleg murder...    215  mspmy8
# 3    myanmar junta leader confirm attend asean meet...     19  msn401
# 4    la counti covid19 posit rate 1 lowest sinc sta...    159  mso9px
# ..                                                 ...    ...     ...
# 441  myanmar releas prison new year though like dissid     24  msoxsd
# 442  video driver jump daytona beach drawbridg cras...     35  mslyla
# 443  second arrest made burleson offic shot woman k...    110  ms11l7
# 444  china resolut oppos us japan joint statement c...     39  msoi0o
# 445  brazil ask women possibl delay pregnanc covid ...     46  mso34l
#
#                                                    url  coms_num  \
# 0    https://abcnews.go.com/US/wireStory/hartford-a...        24
# 1    https://www.firstcoastnews.com/mobile/article/...        78
# 2    https://www.liherald.com/lynbrook/stories/form...        20
# 3    https://www.straitstimes.com/asia/se-asia/myan...         1
# 4    https://abc7.com/health/la-countys-covid-19-po...        10
# ..                                                 ...       ...
# 441  https://www.reuters.com/world/asia-pacific/mya...         3
# 442  https://www.news4jax.com/news/florida/2021/04/...        21
# 443  https://www.nbcdfw.com/news/local/second-arres...        12
# 444  https://www.reuters.com/world/china/china-reso...        20
# 445  https://edition.cnn.com/2021/04/17/americas/br...        10
#
#              author  upvotes  word_count
# 0              -___       45          10
# 1        Jean_Zombi      573           8
# 2        Jean_Zombi      215          16
# 3    notice_me_mina       19          10
# 4      Hermitically      159          12
# ..              ...      ...         ...
# 441   mayurbhattseo       24          10
# 442  brashendeavors       35          11
# 443      Jean_Zombi      110          11
# 444     harsha_shun       39          13
# 445        kksingh1       46          11
#
# [446 rows x 8 columns]

# %%
st = PorterStemmer()
df['title']=df['title'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
df
# Out:
#                                                  title  score      id  \
# 0          hartford agre pay 650m boy scout bankruptci     45  msfits
# 1          jacksonvil pastor arrest accus molest child    573  msplo5
# 2    former nypd offic oceansid involv alleg murder...    215  mspmy8
# 3    myanmar junta leader confirm attend asean meet...     19  msn401
# 4    la counti covid19 posit rate 1 lowest sinc sta...    159  mso9px
# ..                                                 ...    ...     ...
# 441  myanmar releas prison new year though like dissid     24  msoxsd
# 442  video driver jump daytona beach drawbridg cras...     35  mslyla
# 443  second arrest made burleson offic shot woman k...    110  ms11l7
# 444  china resolut oppos us japan joint statement c...     39  msoi0o
# 445  brazil ask women possibl delay pregnanc covid ...     46  mso34l
#
#                                                    url  coms_num  \
# 0    https://abcnews.go.com/US/wireStory/hartford-a...        24
# 1    https://www.firstcoastnews.com/mobile/article/...        78
# 2    https://www.liherald.com/lynbrook/stories/form...        20
# 3    https://www.straitstimes.com/asia/se-asia/myan...         1
# 4    https://abc7.com/health/la-countys-covid-19-po...        10
# ..                                                 ...       ...
# 441  https://www.reuters.com/world/asia-pacific/mya...         3
# 442  https://www.news4jax.com/news/florida/2021/04/...        21
# 443  https://www.nbcdfw.com/news/local/second-arres...        12
# 444  https://www.reuters.com/world/china/china-reso...        20
# 445  https://edition.cnn.com/2021/04/17/americas/br...        10
#
#              author  upvotes  word_count
# 0              -___       45          10
# 1        Jean_Zombi      573           8
# 2        Jean_Zombi      215          16
# 3    notice_me_mina       19          10
# 4      Hermitically      159          12
# ..              ...      ...         ...
# 441   mayurbhattseo       24          10
# 442  brashendeavors       35          11
# 443      Jean_Zombi      110          11
# 444     harsha_shun       39          13
# 445        kksingh1       46          11
#
# [446 rows x 8 columns]
